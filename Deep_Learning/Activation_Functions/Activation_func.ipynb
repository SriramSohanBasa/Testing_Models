# %% [raw]
# Types of Activation Functions
# 	1.	Sigmoid
# 	2.	Tanh (Hyperbolic Tangent)
# 	3.	ReLU (Rectified Linear Unit)
# 	4.	Leaky ReLU
# 	5.	Softmax
# Real-Life Use Cases
# 	•	Sigmoid: Binary classification problems, output layer of neural networks
# 	•	Tanh: Hidden layers in neural networks, especially for data centered around zero
# 	•	ReLU: Most commonly used in hidden layers of deep neural networks, especially in computer vision tasks
# 	•	Leaky ReLU: Alternative to ReLU to address the “dying ReLU” problem
# 	•	Softmax: Output layer for multi-class classification problems
#
#
#
#
# Impact on Models
# 	•	Introduce non-linearity, allowing networks to learn complex patterns
# 	•	Affect the speed of training and convergence
# 	•	Influence the network’s ability to handle vanishing or exploding gradients
# 	•	Determine the range of output values
# Graphs
# 	•	Sigmoid: S-shaped curve, output range (0, 1)
# 	•	Tanh: S-shaped curve, output range (-1, 1)
# 	•	ReLU: Linear for positive inputs, zero for negative inputs
# 	•	Leaky ReLU: Similar to ReLU, but with a small slope for negative inputs
# 	•	Softmax: Exponential function normalized to sum to 1

# %%
# Activation Functions in Neural Networks

## Types of Activation Functions

# 1. Sigmoid
# 2. Tanh (Hyperbolic Tangent)
# 3. ReLU (Rectified Linear Unit)
# 4. Leaky ReLU
# 5. Softmax

## Formulas and Graphs


import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

x = np.linspace(-10, 10, 1000)

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(x, sigmoid(x))
plt.title('Sigmoid')
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x, tanh(x))
plt.title('Tanh')
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(x, relu(x))
plt.title('ReLU')
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x, leaky_relu(x))
plt.title('Leaky ReLU')
plt.grid(True)

plt.tight_layout()
plt.show()

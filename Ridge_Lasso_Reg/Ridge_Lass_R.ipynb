# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('Algerian_forest_fires_dataset.csv')

# %%
dataset.head(
    
)
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# ##data cleaning

# %%
##missing values

dataset[dataset.isnull().any(axis=1)]
dataset.drop(index=121)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
dataset.loc[:122,"Region"] = 0
dataset.loc[122:,"Region"]=1

# %%
df = dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
##remove null values
df=df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df.iloc[115:130]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 115   24      9  2012           29   65   19    0.6  68.3  5.5  15.2  1.5
# 116   25      9  2012           26   81   21    5.8  48.6    3   7.7  0.4
# 117   26      9  2012           31   54   11      0    82    6  16.3  2.5
# 118   27      9  2012           31   66   11      0  85.7  8.3  24.9    4
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4    45  1.9   7.5  0.2
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 123    1      6  2012           32   71   12    0.7  57.1  2.5   8.2  0.6
# 124    2      6  2012           30   73   13      4  55.7  2.7   7.8  0.6
# 125    3      6  2012           29   80   14      2  48.7  2.2   7.6  0.3
# 126    4      6  2012           30   64   14      0  79.4  5.2  15.4  2.2
# ...

# %%
##removed 121 and then reset index
df = df.drop(index=122).reset_index(drop=True)

# %%
df.iloc[115:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 115  24     9  2012          29  65  19   0.6  68.3  5.5  15.2  1.5   5.8
# 116  25     9  2012          26  81  21   5.8  48.6    3   7.7  0.4     3
# 117  26     9  2012          31  54  11     0    82    6  16.3  2.5   6.2
# 118  27     9  2012          31  66  11     0  85.7  8.3  24.9    4     9
# 119  28     9  2012          32  47  14   0.7  77.5  7.1   8.8  1.8   6.8
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3     3
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 122   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 123   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 124   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 125   5     6  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 126   6     6  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
##fix spaces in column names
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    object
#  1   month        242 non-null    object
#  2   year         242 non-null    object
#  3   Temperature  242 non-null    object
#  4   RH           242 non-null    object
#  5   Ws           242 non-null    object
#  6   Rain         242 non-null    object
#  7   FFMC         242 non-null    object
#  8   DMC          242 non-null    object
#  9   DC           242 non-null    object
#  10  ISI          242 non-null    object
#  11  BUI          242 non-null    object
#  12  FWI          242 non-null    object
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.5+ KB

# %%
##change the required columns as integer
df[['month','day','year','Temperature','RH','Ws']] = df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    object
#  7   FFMC         242 non-null    object
#  8   DMC          242 non-null    object
#  9   DC           242 non-null    object
#  10  ISI          242 non-null    object
#  11  BUI          242 non-null    object
#  12  FWI          242 non-null    object
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.5+ KB

# %%
##changing the other columns to float


objects=[features for features in df.columns if df[features].dtypes=='O']

# %%
for i in objects:
    if i!='Classes':
        df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.5+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  242.000000  242.000000   242.0   242.000000  242.000000  242.000000
# mean    15.822314    7.508264  2012.0    32.152893   62.004132   15.508264
# std      8.809501    1.112888     0.0     3.635545   14.847635    2.808171
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.250000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.750000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  242.000000  242.000000  242.000000  242.000000  242.000000  242.000000
# mean     0.763223   77.928099   14.730992   49.601240    4.759504   16.747934
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
##exporting the cleaned dataset
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv', index=False)

# %%
##data analysis

# %%
##df copy
dfc = df

# %%
dfc = df.drop(['day','month','year'],axis=1)

# %%
dfc.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  242 non-null    int64
#  1   RH           242 non-null    int64
#  2   Ws           242 non-null    int64
#  3   Rain         242 non-null    float64
#  4   FFMC         242 non-null    float64
#  5   DMC          242 non-null    float64
#  6   DC           242 non-null    float64
#  7   ISI          242 non-null    float64
#  8   BUI          242 non-null    float64
#  9   FWI          242 non-null    float64
#  10  Classes      242 non-null    object
#  11  Region       242 non-null    int64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 22.8+ KB

# %%
##encoding of the category in class

dfc['Classes'] = dfc['Classes'].apply(lambda x: 0 if isinstance(x, str) and 'not fire' in x else 1)

# %%
dfc.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
dfc['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    105
# Name: count, dtype: int64

# %%
##visualisation, plot density

plt.style.use('seaborn-v0_8')
dfc.hist(bins=50, figsize=(20,15))
plt.show()

# %%
##percentage for pie chart of fire

percentage=dfc['Classes'].value_counts(normalize=True)*100

# %%
classlabels=['Fire','Not Fire']
plt.figure(figsize=(5,7))
plt.pie(percentage, labels = classlabels, autopct='%1.1f%%')
plt.show()

# %%
##correlation
dfc.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651791 -0.285644 -0.326499  0.679270  0.486494
# RH             -0.651791  1.000000  0.248148  0.222604 -0.644536 -0.407180
# Ws             -0.285644  0.248148  1.000000  0.171896 -0.175324 -0.005819
# Rain           -0.326499  0.222604  0.171896  1.000000 -0.546470 -0.289482
# FFMC            0.679270 -0.644536 -0.175324 -0.546470  1.000000  0.601527
# DMC             0.486494 -0.407180 -0.005819 -0.289482  0.601527  1.000000
# DC              0.376720 -0.225293  0.075031 -0.298600  0.505185  0.875511
# ISI             0.604948 -0.686103  0.003408 -0.348334  0.738754  0.679150
# BUI             0.460533 -0.352357  0.026542 -0.300574  0.589881  0.982178
# FWI             0.567506 -0.580109  0.027768 -0.325112  0.689822  0.875405
# Classes         0.517203 -0.430794 -0.076262 -0.380263  0.768069  0.583760
# ...

# %%
sns.heatmap(dfc.corr())
# Out:
# <Axes: >

# %%
##boxplot for outliers


sns.boxplot(x=dfc['FWI'])
# Out:
# <Axes: xlabel='FWI'>

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
##encoding of the category in class

df['Classes'] = df['Classes'].apply(lambda x: 'not fire' if isinstance(x, str) and 'not fire' in x else 'fire')

# %%
##monthly fire analysis
dftemp=df.loc[df['Region'] == 1]
plt.subplots(figsize = (10,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes' , data=df)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
##monthly fire analysis
dftemp=df.loc[df['Region'] == 0]
plt.subplots(figsize = (10,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes' , data=df)
# Out:
# <Axes: xlabel='month', ylabel='count'>
